# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time, cv = np.loadtxt('COLVAR', unpack=True, usecols=(0,1))

# %%
np.std(cv) # will be roughly the sigma used in metadynamics
# Out:
# 1.2763975455953698

# %%
fig = plt.figure(figsize=(5,4))
ax = fig.subplots(nrows=1, ncols=1)

ax.plot(time, cv)

plt.show()
